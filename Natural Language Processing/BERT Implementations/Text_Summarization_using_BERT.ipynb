# %% [markdown]
# # **Extractive Text Summarization using BERT**

# %%
pip install bert-extractive-summarizer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert-extractive-summarizer
#   Downloading bert_extractive_summarizer-0.10.1-py3-none-any.whl (25 kB)
# Collecting transformers (from bert-extractive-summarizer)
#   Downloading transformers-4.30.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 79.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from bert-extractive-summarizer) (1.2.2)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from bert-extractive-summarizer) (3.5.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-extractive-summarizer) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-extractive-summarizer) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-extractive-summarizer) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->bert-extractive-summarizer) (3.1.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (8.1.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (1.1.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (0.10.1)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (1.10.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy->bert-extractive-summarizer) (3.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->bert-extractive-summarizer) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers->bert-extractive-summarizer)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->bert-extractive-summarizer) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->bert-extractive-summarizer) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers->bert-extractive-summarizer)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 131.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers->bert-extractive-summarizer)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->bert-extractive-summarizer) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers->bert-extractive-summarizer) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy->bert-extractive-summarizer) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->bert-extractive-summarizer) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy->bert-extractive-summarizer) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy->bert-extractive-summarizer) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy->bert-extractive-summarizer) (2.1.2)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers, bert-extractive-summarizer
# Successfully installed bert-extractive-summarizer-0.10.1 huggingface-hub-0.15.1 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.30.2

# %% [markdown]
# # **Simple Example**

# %%
from summarizer import Summarizer

# %%
body = "The text body that you wanted to summarizer with BERT"
body2 = "This is a random content that you wanted to summarizer with the BERT model"
model = Summarizer()
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
kamalHaasanBio = "Kamal Haasan, a renowned Indian actor, filmmaker, and politician, has left an indelible mark on the world of cinema and beyond. With a career spanning over five decades, Haasan has emerged as a versatile and influential figure, pushing the boundaries of artistic expression and societal impact. Haasan's commitment to his craft is evident in the diverse range of roles he has portrayed onscreen. From intense dramatic performances to comedic genius, he has showcased his exceptional acting prowess in films across various genres. His ability to effortlessly inhabit complex characters has earned him critical acclaim and numerous accolades, including several National Film Awards. Beyond his acting, Haasan's contributions to the Indian film industry are far-reaching. He has explored unconventional narratives, tackling social issues and challenging societal norms through his films. As a writer and director, he has helmed projects that have sparked conversations and provoked thought, further establishing his reputation as a visionary filmmaker. In addition to his cinematic achievements, Haasan has also ventured into politics, using his platform to address social and political concerns. His political career has been marked by his outspoken nature and his willingness to confront and discuss controversial topics. He has been an advocate for social justice, championing causes such as education, healthcare, and gender equality. Kamal Haasan's impact extends beyond his artistic and political endeavors. He is a cultural icon, inspiring generations of actors and filmmakers with his dedication, versatility, and fearlessness. His influence on Indian cinema has been recognized globally, earning him prestigious honors such as the Padma Shri and Padma Bhushan awards. In conclusion, Kamal Haasan's multifaceted career as an actor, filmmaker, and politician has solidified his status as a true legend in the world of cinema. His remarkable talent, coupled with his commitment to social change and his fearlessness in tackling important issues, has made him an iconic figure. Kamal Haasan's contributions have shaped Indian cinema and continue to inspire and entertain audiences across the globe. "

# %%
kamalHaasanBioSumm = model(kamalHaasanBio, num_sentences=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kamalHaasanBioSumm
# Out:
# "Kamal Haasan, a renowned Indian actor, filmmaker, and politician, has left an indelible mark on the world of cinema and beyond. Kamal Haasan's contributions have shaped Indian cinema and continue to inspire and entertain audiences across the globe."

# %%
model(body2)
# Out:
# 'This is a random content that you wanted to summarizer with the BERT model'

# %% [markdown]
# Using multiple hidden layers for embedding

# %%
articleOnSuperHeroes = "DC Comics, a powerhouse in the realm of comic book storytelling, has captivated readers for decades with its iconic characters and immersive narratives. Founded in 1934, DC Comics has established itself as a cultural phenomenon, shaping the landscape of superhero fiction and leaving an indelible mark on popular culture. With legendary superheroes like Superman, Batman, Wonder Woman, and the Justice League, DC Comics has crafted a vast and intricate universe that resonates with fans of all ages. One of the defining features of DC Comics is its commitment to compelling character development. From the tragic origins of Batman, driven by a desire to avenge his parents' murder, to the righteous determination of Superman, a symbol of hope and justice, these characters embody a rich tapestry of complex emotions and motivations. Each hero and villain is crafted with depth and nuance, allowing readers to explore their struggles, triumphs, and the moral dilemmas they face. DC Comics is also known for its sprawling multiverse, a tapestry of interconnected worlds and alternate realities. This narrative device allows for diverse interpretations of beloved characters and storylines, inviting readers to explore infinite possibilities. From the gritty and dark atmosphere of Gotham City to the majestic and mythical realms of Themyscira, DC Comics offers a diverse array of settings, each with its own unique flavor and atmosphere. Over the years, DC Comics has expanded its storytelling beyond the pages of comics, with successful adaptations in film, television, and other media. These adaptations have introduced DC's characters to a wider audience, reinforcing their enduring popularity and cultural significance. In conclusion, DC Comics has become a titan in the world of comic book publishing, captivating audiences with its unforgettable characters, intricate narratives, and boundless imagination. With its rich history and enduring legacy, DC Comics continues to inspire and entertain fans around the globe."

# %%
model1 = Summarizer('distilbert-base-uncased', hidden=[-1, -2], hidden_concat=True)
result1 = model1(body = articleOnSuperHeroes, ratio=0.2, num_sentences=3)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
result1
# Out:
# 'DC Comics, a powerhouse in the realm of comic book storytelling, has captivated readers for decades with its iconic characters and immersive narratives. Over the years, DC Comics has expanded its storytelling beyond the pages of comics, with successful adaptations in film, television, and other media. In conclusion, DC Comics has become a titan in the world of comic book publishing, captivating audiences with its unforgettable characters, intricate narratives, and boundless imagination.'

# %% [markdown]
# # **Using SBert (Sentence Bert)**

# %%
pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.30.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=3121b41051e4161032887606564754382c1c42316819ff98bd473499f89d09a9
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.99

# %%
from summarizer.sbert import SBertSummarizer

# %%
movieReview = "Schindler's List, directed by Steven Spielberg, is a cinematic masterpiece that confronts the harrowing realities of the Holocaust with unflinching honesty and profound humanity. Set during World War II, the film follows the true story of Oskar Schindler, a German businessman who saves over a thousand Jewish lives by employing them in his factories. From the opening scene, Spielberg's masterful storytelling grips the viewer's heart, plunging them into the dark depths of Nazi-occupied Poland. The stark black and white cinematography serves as a haunting visual reminder of the moral complexities and the stark contrast between good and evil. The attention to detail and historical accuracy immerses the audience in a time and place that must never be forgotten. Liam Neeson delivers a tour de force performance as Oskar Schindler, capturing his transformation from a self-interested opportunist to a righteous hero. Neeson's portrayal is layered with nuance, depicting Schindler's internal struggle and gradual realization of the horrors unfolding around him. Equally mesmerizing is Ralph Fiennes as Amon Goeth, the sadistic Nazi officer. Fiennes brings chilling authenticity to the role, embodying the monstrous cruelty that characterized the Holocaust. Spielberg's direction is nothing short of masterful, combining epic storytelling with intimate moments of profound emotion. The film's pacing is deliberate, allowing each scene to breathe and leaving a lasting impact on the viewer. Spielberg's use of long takes and meticulous attention to detail elevates the film, creating an immersive experience that resonates long after the credits roll. What truly sets Schindler's List apart is its unflinching portrayal of the atrocities committed during the Holocaust. The film does not shy away from the brutal reality of genocide, showcasing the horrors faced by Jews in concentration camps and the unspeakable acts of violence perpetrated against them. Yet, amidst this darkness, Spielberg weaves a thread of hope and humanity. Through Schindler's acts of courage and compassion, the film highlights the power of one individual to make a difference and reminds us of the resilience of the human spirit. Schindler's List is not an easy film to watch. It forces us to confront the depths of human depravity and the fragility of life. However, it is a necessary film, a poignant and unapologetic reminder of the atrocities of the past and a call to action against injustice in the present. It serves as a testament to the power of cinema to educate, to provoke, and to inspire change. In conclusion, Schindler's List stands as a monumental achievement in filmmaking. Spielberg's visionary direction, coupled with powerful performances and a gripping narrative, creates an indelible cinematic experience. It is a film that demands our attention, challenges our perceptions, and reminds us of the enduring importance of remembrance and empathy. Schindler's List is a haunting and profoundly moving testament to the triumph of the human spirit in the face of unimaginable evil. "

# %%
sBertModel = SBertSummarizer('paraphrase-MiniLM-L6-v2')
movieReviewSummary = sBertModel(movieReview, num_sentences=2)
# Out:
# Downloading (…)001fa/.gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)3bbb8001fa/README.md:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# Downloading (…)bb8001fa/config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)001fa/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# Downloading (…)3bbb8001fa/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)b8001fa/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
movieReviewSummary
# Out:
# "Schindler's List, directed by Steven Spielberg, is a cinematic masterpiece that confronts the harrowing realities of the Holocaust with unflinching honesty and profound humanity. However, it is a necessary film, a poignant and unapologetic reminder of the atrocities of the past and a call to action against injustice in the present."

# %% [markdown]
# # **Retrieving Embeddings:**
# Retrieving the embeddings of the summarization:
# Embeddings are the vector representation of the summary, where the context and the relationship of the summary is depicted.

# %%
embeddingResults = model.run_embeddings(kamalHaasanBio, num_sentences=3, aggregate='mean')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
embeddingResults
# Out:
# array([-0.26961836, -0.30540904, -0.38189602, ..., -0.0040268 ,
#         0.53921825,  0.22840178], dtype=float32)

# %% [markdown]
# # **Custom Model Example**

# %%
from transformers import *

#Load Model, model config and tokenizer via Transformers

custom_config = AutoConfig.from_pretrained('allenai/scibert_scivocab_uncased')
custom_config.output_hidden_states = True
custom_tokenizer = AutoTokenizer.from_pretrained('allenai/scibert_scivocab_uncased')
custom_model = AutoModel.from_pretrained('allenai/scibert_scivocab_uncased', config=custom_config )
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--allenai--scibert_scivocab_uncased/snapshots/24f92d32b1bfb0bcaf9ab193ff3ad01e87732fc1/config.json
# Model config BertConfig {
#   "_name_or_path": "allenai/scibert_scivocab_uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 31090
# }
#
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--allenai--scibert_scivocab_uncased/snapshots/24f92d32b1bfb0bcaf9ab193ff3ad01e87732fc1/config.json
# Model config BertConfig {
#   "_name_or_path": "allenai/scibert_scivocab_uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 31090
# }
#
# loading file vocab.txt from cache at /root/.cache/huggingface/hub/models--allenai--scibert_scivocab_uncased/snapshots/24f92d32b1bfb0bcaf9ab193ff3ad01e87732fc1/vocab.txt
# loading file tokenizer.json from cache at None
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--allenai--scibert_scivocab_uncased/snapshots/24f92d32b1bfb0bcaf9ab193ff3ad01e87732fc1/config.json
# Model config BertConfig {
#   "_name_or_path": "allenai/scibert_scivocab_uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 31090
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--allenai--scibert_scivocab_uncased/snapshots/24f92d32b1bfb0bcaf9ab193ff3ad01e87732fc1/config.json
# Model config BertConfig {
#   "_name_or_path": "allenai/scibert_scivocab_uncased",
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.30.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 31090
# }
#
# loading weights file pytorch_model.bin from cache at /root/.cache/huggingface/hub/models--allenai--scibert_scivocab_uncased/snapshots/24f92d32b1bfb0bcaf9ab193ff3ad01e87732fc1/pytorch_model.bin
# Some weights of the model checkpoint at allenai/scibert_scivocab_uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at allenai/scibert_scivocab_uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.

# %%
from summarizer import Summarizer

articleOnMessiVsRonaldo = '''The ongoing debate surrounding Lionel Messi and Cristiano Ronaldo as the greatest of all time (GOAT) is one that captivates football fans worldwide. 
Both players have redefined the sport, shattered countless records, and achieved unprecedented success. However, the question of who deserves the title of the GOAT remains fiercely 
contested. On one hand, Lionel Messis mesmerizing dribbling skills, close control, and innate vision make him a true artist on the pitch. His ability to effortlessly glide past defenders, 
combined with his impeccable passing and exceptional goal-scoring record, has earned him numerous accolades. Messis consistency and loyalty to FC Barcelona, where he spent the majority of 
his career, have also endeared him to fans around the globe. On the other hand, Cristiano Ronaldos sheer athleticism, raw power, and relentless work ethic are undeniable. His towering 
headers, rocket-like shots, and remarkable physicality make him an unparalleled force in the game. Ronaldos incredible goal-scoring prowess, which he has displayed for Manchester United, 
Real Madrid, Juventus, and the Portuguese national team, showcases his versatility and adaptability. Determining the GOAT ultimately boils down to personal preference. Messis elegance and 
finesse may resonate with those who appreciate the artistry of the game, while Ronaldos athleticism and relentless pursuit of excellence may appeal to fans who value power and 
determination. Both players have amassed an astonishing array of individual and team honors, including multiple FIFA Ballon d Or awards. Regardless of ones stance in the Messi-Ronaldo 
debate, it is undeniable that these two footballing giants have left an indelible mark on the sport. Their rivalry has elevated the game to new heights, inspiring generations of aspiring
 players to push their limits and strive for greatness. In conclusion, the Messi-Ronaldo debate is a testament to the unparalleled talent and influence of these extraordinary athletes. 
 While opinions may differ, one thing remains clear: Messi and Ronaldo have set the bar impossibly high, forever changing the landscape of football and etching their names in the annals of 
 sporting history. The debate over who deserves the title of the greatest of all time (GOAT) in football between Lionel Messi and Cristiano Ronaldo has been a topic of heated discussion among
  fans, pundits, and experts for over a decade. Both players have consistently delivered exceptional performances and achieved remarkable success, making the decision a challenging one. 
  Lionel Messi, known for his incredible dribbling skills, agility, and close control, has an innate ability to maneuver past defenders effortlessly. His vision on the pitch allows him
   to create scoring opportunities for himself and his teammates, making him a playmaker of the highest caliber. Messis record-breaking goal-scoring exploits, combined with his impeccable
    passing and ability to navigate through tight spaces, have garnered him numerous individual awards, including a record-breaking seven FIFA Ballon dOr titles. On the other hand, 
    Cristiano Ronaldo is renowned for his incredible athleticism, raw power, and goal-scoring prowess. His towering presence and aerial ability make him a lethal threat in the box,
     while his long-range shooting and clinical finishing are unmatched. Ronaldos relentless work ethic, dedication to physical fitness, and hunger for success have propelled him to win 
     numerous domestic and international titles, along with five FIFA Ballon dOr awards. The comparison between Messi and Ronaldo extends beyond their individual achievements. 
     Messi has spent the majority of his career at Barcelona, becoming synonymous with the clubs style of play and winning numerous domestic and international titles, including the UEFA 
     Champions League. Ronaldo, on the other hand, has achieved success with multiple top European clubs, including Manchester United, Real Madrid, and Juventus, showcasing his adaptability
      and ability to excel in different environments. When evaluating the GOAT debate, personal preferences and biases often come into play. Some argue that Messi's natural talent, 
      creativity, and ability to make the game appear effortless make him the epitome of the beautiful game. Others favor Ronaldo's physical prowess, work ethic, and relentless desire to be
       the best, considering him a true embodiment of dedication and determination. It is worth noting that football is a team sport, and the success of a player cannot be solely attributed 
       to individual brilliance. Both Messi and Ronaldo have played with exceptional teammates who have contributed to their achievements. Additionally, the GOAT debate is subjective, 
       influenced by factors such as generational bias, regional loyalties, and personal affinities. In the end, the Messi-Ronaldo debate is likely to continue indefinitely, as both players
        have left an indelible mark on the sport. Their exceptional skills, records, and achievements have raised the bar for future generations, inspiring young players to strive for
 greatness. Ultimately, the answer to who is the true GOAT may never be definitively settled, as the debate is driven by personal opinions and individual interpretations of greatness.'''
customSummModel = Summarizer(custom_model=custom_model, custom_tokenizer=custom_tokenizer)

# %%
summOnMessiVsRonaldo = customSummModel(body=articleOnMessiVsRonaldo)
summOnMessiVsRonaldo
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# "The ongoing debate surrounding Lionel Messi and Cristiano Ronaldo as the greatest of all time (GOAT) is one that captivates football fans worldwide. Regardless of ones stance in the Messi-Ronaldo \ndebate, it is undeniable that these two footballing giants have left an indelible mark on the sport. Their rivalry has elevated the game to new heights, inspiring generations of aspiring\n players to push their limits and strive for greatness. On the other hand, \n    Cristiano Ronaldo is renowned for his incredible athleticism, raw power, and goal-scoring prowess. The comparison between Messi and Ronaldo extends beyond their individual achievements. Messi has spent the majority of his career at Barcelona, becoming synonymous with the clubs style of play and winning numerous domestic and international titles, including the UEFA \n     Champions League. Others favor Ronaldo's physical prowess, work ethic, and relentless desire to be\n       the best, considering him a true embodiment of dedication and determination. Ultimately, the answer to who is the true GOAT may never be definitively settled, as the debate is driven by personal opinions and individual interpretations of greatness."

# %% [markdown]
# # **Calculate ELBOW**

# %%
elbow = customSummModel.calculate_elbow(articleOnMessiVsRonaldo, k_max=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
elbow
# Out:
# [1581.650390625,
#  1425.2103271484375,
#  1303.2353515625,
#  1239.869140625,
#  1159.6697998046875,
#  1104.2374267578125,
#  1035.4453125,
#  999.8460083007812,
#  947.2556762695312]

# %%
optimalSentences = customSummModel.calculate_optimal_k(articleOnMessiVsRonaldo, k_max=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
optimalSentences
# Out:
# 3

# %%
optimalGOATDebate = customSummModel(articleOnMessiVsRonaldo, num_sentences=3)
optimalGOATDebate
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 'The ongoing debate surrounding Lionel Messi and Cristiano Ronaldo as the greatest of all time (GOAT) is one that captivates football fans worldwide. While opinions may differ, one thing remains clear: Messi and Ronaldo have set the bar impossibly high, forever changing the landscape of football and etching their names in the annals of \n sporting history. Ronaldo, on the other hand, has achieved success with multiple top European clubs, including Manchester United, Real Madrid, and Juventus, showcasing his adaptability\n      and ability to excel in different environments.'
